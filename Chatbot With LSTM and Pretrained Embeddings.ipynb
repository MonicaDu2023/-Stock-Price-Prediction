# %% [markdown]
# # Project Overview

# %% [markdown]
# In this project, I will build a chatbot that can converse with you at the command line. The chatbot will use a Sequence to Sequence text generation architecture with an LSTM as it's memory unit. You will also learn to use pretrained word embeddings to improve the performance of the model. At the conclusion of the project, you will be able to show your chatbot to potential employers.
#
# Additionally, you have the option to use pretrained word embeddings in your model. We have loaded Brown Embeddings from Gensim in the starter code below. You can compare the performance of your model with pre-trained embeddings against a model without the embeddings.
#
# A sequence to sequence model (Seq2Seq) has two components:
#
# An Encoder consisting of an embedding layer and LSTM unit.
# A Decoder consisting of an embedding layer, LSTM unit, and linear output unit.
# The Seq2Seq model works by accepting an input into the Encoder, passing the hidden state from the Encoder to the Decoder, which the Decoder uses to output a series of token predictions.

# %%
import gensim
import nltk
import numpy as np
import pandas as pd
import gzip
import torch
from nltk.corpus import brown
from torchtext.datasets import SQuAD1
import string
import torch.nn as nn
import random 
from sklearn.model_selection import KFold
from datetime import datetime

stemmer = nltk.stem.snowball.SnowballStemmer('english')

nltk.download('brown')
nltk.download('punkt')

# Output, save, and load brown embeddings

model = gensim.models.Word2Vec(brown.sents())
model.save('brown.embedding')

w2v = gensim.models.Word2Vec.load('brown.embedding')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# [nltk_data] Downloading package brown to /Users/ante/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/ante/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def loadDF(path):
    
    dataset_train, dataset_dev = SQuAD1(root = path, split = ('train', 'dev'))

    df_train = pd.DataFrame.from_dict(dataset_train)
    df_dev = pd.DataFrame.from_dict(dataset_dev)
    
    df = df_train.append(df_dev)
    
    return df

# %%
df = loadDF('.data')

feature = ["Sentence", "Question", "Answer", "?"]
df.columns = feature

df.head()
# Out:
# train-v1.1.json: 30.3MB [00:00, 46.9MB/s]
# dev-v1.1.json: 4.85MB [00:00, 44.8MB/s]
#                                             Sentence  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
# 2  Architecturally, the school has a Catholic cha...
# 3  Architecturally, the school has a Catholic cha...
# 4  Architecturally, the school has a Catholic cha...
#
#                                             Question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# 4  What sits on top of the Main Building at Notre...
#
#                                       Answer      ?
# 0               [Saint Bernadette Soubirous]  [515]
# 1                [a copper statue of Christ]  [188]
# 2                        [the Main Building]  [279]
# 3  [a Marian place of prayer and reflection]  [381]
# 4       [a golden statue of the Virgin Mary]   [92]

# %%
SOS_token = 0
EOS_token = 1

class Chatbot:
    def __init__(self):
        #initialize containers to hold the words and corresponding index
        self.word2index = {"": SOS_token, "": EOS_token}
        self.index2word = {SOS_token: "", EOS_token: ""}
        self.words_count = len(self.word2index)
        
    def add_Sentence(self, sentence):
        #split a sentence into words and add it to the container
        for word in sentence.split(' '):
            self.add_words(word)

    def add_words(self, word):
        #If the word is not in the container, the word will be added to it
        if word not in self.word2index:
            self.word2index[word] = self.words_count
            self.index2word[self.words_count] = word
            self.words_count += 1

# %%
#Normalize every sentence
def normalize_sentence(sentence):
    
    sentence = ''.join([s.lower() for s in sentence if s not in string.punctuation])
    sentence = ' '.join(stemmer.stem(w) for w in sentence.split())
    tokens = nltk.tokenize.RegexpTokenizer(r'\w+').tokenize(sentence)
    
    return tokens

def read_sentence(df, col1, col2):
    
    df[col1] = df[col1].apply(normalize_sentence)
    sentence1 = df[col1].apply(lambda x: " ".join(x)).to_list()
    df[col2] = df[col2].apply(normalize_sentence)
    sentence2 = df[col2].apply(lambda x: " ".join(x) ).to_list()
    
    return list(sentence1), list(sentence2)

def getMaxLen(sentence):
    
    max_len = 0 
    
    for s in sentence:
        max_len = len(s) if len(s) > max_len else max_len
        
    return max_len

# %%
def process_data(df, col1, col2):
    
    sentence1, sentence2 = read_sentence(df, col1, col2)
    
    source = Chatbot()
    target = Chatbot()
    pairs = []
    
    max_lens = getMaxLen(sentence1)
    max_lenc = getMaxLen(sentence2)
    for i in range(len(df)):
        if len(sentence1[i]) <= max_lens and len(sentence2[i]) <= max_lenc:
            full = [sentence1[i], sentence2[i]]
            source.add_Sentence(sentence1[i])
            target.add_Sentence(sentence2[i])
            pairs.append(full)
    
    return source, target, pairs

# %%
source, target, pairs = process_data(df, 'Question', 'Answer')

# %%
pairs[0]
# Out:
# ['to whom did the virgin mari alleg appear in 1858 in lourd franc',
#  'saint bernadett soubir']

# %%
source, target
# Out:
# (<__main__.Chatbot at 0x1a308a2d68>, <__main__.Chatbot at 0x1a2c2c6940>)

# %%
#converting pairs into Tensor.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def indexesFromSentence(chatbot, sentence):
    return [chatbot.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(chatbot, sentence):
    indexes = indexesFromSentence(chatbot, sentence)
    indexes.append(chatbot.word2index[''])
    return torch.Tensor(indexes).long().to(device).view(-1, 1)

def tensorsFromPair(source, target, pairs):
    source_data = []
    target_data = []
    for pair in pairs:
        source_data.append(tensorFromSentence(source, pair[0]))
        target_data.append(tensorFromSentence(target, pair[1]))
    return source_data, target_data

# %%
source_data, target_data = tensorsFromPair(source, target, pairs)

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(Encoder, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        
        self.embedding = nn.Embedding(self.input_size, self.hidden_size)
        # The LSTM is our last cell because it produces the hidden state
        self.lstm = nn.LSTM(self.hidden_size, self.hidden_size)

    def forward(self, x, hidden, cell_state):
        
        x = self.embedding(x).view(1, 1, -1)
        x, (hidden, cell_state) = self.lstm(x, (hidden, cell_state))
        
        #outputs are always from the top hidden layer
        return x, hidden, cell_state

# %%
class Decoder(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(Decoder, self).__init__()
        
        self.hidden_size = hidden_size
        self.output_size = output_size
        
        # initialize every layer with the appropriate dimension.
        self.embedding = nn.Embedding(output_size, self.hidden_size)
        self.lstm = nn.LSTM(self.hidden_size, self.hidden_size)
        self.fc = nn.Linear(self.hidden_size, self.output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, x, hidden, cell_state):
        
        # reshape the input to (1, 1, batch_size)
        x = self.embedding(x).view(1, 1, -1)
        x, (hidden, cell_state) = self.lstm(x, (hidden, cell_state))
        x = self.softmax(self.fc(x[0]))
        
        return x, hidden, cell_state

# %%
class Seq2Seq(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(Seq2Seq, self).__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        
        #initialize the encoder and decoder
        self.encoder = Encoder(self.input_size, self.hidden_size)
        self.decoder = Decoder(self.hidden_size, self.output_size)
        
    def forward(self, src, trg, src_len, trg_len, teacher_force=1):
        
        #initialize a variable to hold the predicted outputs
        output = {'decoder_output':[]}
        
        encoder_hidden = torch.zeros([1, 1, self.hidden_size]).to(device) 
        cell_state = torch.zeros([1, 1, self.hidden_size]).to(device)  
        
        for i in range(src_len):
            encoder_output, encoder_hidden, cell_state = self.encoder(src[i], encoder_hidden, cell_state)

        #use the encoder’s hidden layer as the decoder hidden
        decoder_input = torch.Tensor([[0]]).long().to(device) 
        decoder_hidden = encoder_hidden
        
        #predict the output word from the current target word.
        for i in range(trg_len):
            decoder_output, decoder_hidden, cell_state = self.decoder(decoder_input, decoder_hidden, cell_state)
            output['decoder_output'].append(decoder_output)
            
            if self.training: 
                decoder_input = target_tensor[i] if random.random() > teacher_force else decoder_output.argmax(1) 
            else:
                _, top_index = decoder_output.data.topk(1)
                decoder_input = top_index.squeeze().detach()
                
        return output

# %%
def train(source_data, target_data, model, epochs, batch_size, print_every, learning_rate):
    
    model.to(device)
    total_training_loss = 0
    total_valid_loss = 0
    loss = 0
    
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()

    kf = KFold(n_splits=epochs, shuffle=True)

    for e, (train_index, test_index) in enumerate(kf.split(source_data), 1):
        model.train()
        for i in range(0, len(train_index)):

            src = source_data[i]
            trg = target_data[i]

            output = model(src, trg, src.size(0), trg.size(0))

            #calculate the loss from a predicted sentence with the expected result
            current_loss = 0
            for (s, t) in zip(output["decoder_output"], trg): 
                current_loss += criterion(s, t)

            loss += current_loss
            total_training_loss += (current_loss.item() / trg.size(0))

            if i % batch_size == 0 or i == (len(train_index)-1):
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss = 0

        model.eval()
        for i in range(0, len(test_index)):
            src = source_data[i]
            trg = target_data[i]

            output = model(src, trg, src.size(0), trg.size(0))

            current_loss = 0
            for (s, t) in zip(output["decoder_output"], trg): 
                current_loss += criterion(s, t)

            total_valid_loss += (current_loss.item() / trg.size(0))

        if e % print_every == 0:
            training_loss_average = total_training_loss / (len(train_index)*print_every)
            validation_loss_average = total_valid_loss / (len(test_index)*print_every)
            print("{}/{} Epoch  -  Training Loss = {:.4f}  -  Validation Loss = {:.4f}".format(e, epochs, training_loss_average, validation_loss_average))
            total_training_loss = 0
            total_valid_loss = 0

# %%
hidden_size = 128

seq2seq = Seq2Seq(source.words_count, hidden_size, target.words_count)

# %%
learning_rate = 0.1
batch_size = 128
epochs = 50
train(source_data = source_data,
      target_data = target_data,
      model = seq2seq,
      epochs = epochs,
      batch_size = batch_size,
      print_every = 5,
      learning_rate = learning_rate)
# Out:
# 0/50 Epoch  -  Training Loss = 11.2148  -  Validation Loss = 6.5352
# 5/50 Epoch  -  Training Loss = 9.0778  -  Validation Loss = 6.6216
# 10/50 Epoch  -  Training Loss = 6.3157  -  Validation Loss = 6.4931
# 15/50 Epoch  -  Training Loss = 8.9279  -  Validation Loss = 12.6267
# 20/50 Epoch  -  Training Loss = 7.9184  -  Validation Loss = 6.1722
# 25/50 Epoch  -  Training Loss = 5.9953  -  Validation Loss = 6.8249
# 30/50 Epoch  -  Training Loss = 5.4673  -  Validation Loss = 4.4526
# 35/50 Epoch  -  Training Loss = 5.3805  -  Validation Loss = 3.8604
# 40/50 Epoch  -  Training Loss = 5.0533  -  Validation Loss = 4.6428
# 45/50 Epoch  -  Training Loss = 6.4695  -  Validation Loss = 6.4215
# 50/50 Epoch  -  Training Loss = 6.6867  -  Validation Loss = 6.7893

# %%
def evaluate(source, target, pairs, model, target_max_len):

    source_data, target_data = tensorsFromPair(source, target, pairs)
    answer_words = []
    
    output = model(source_data[0], None, source_data[0].size(0), target_max_len)

    for tensor in output['decoder_output']:

        top_v, top_token = tensor.data.topk(1)
        
        if top_token.item() == EOS_token:
            #answer_words.append('<EOS>')
            continue
        else:
            word = target.index2word[top_token.item()]
            answer_words.append(word)
            
    print(' '.join(answer_words), "\n")

# %%
torch.save(seq2seq, 'seq2seq.pt')

seq2seq = torch.load('seq2seq.pt')
seq2seq.eval()
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (embedding): Embedding(30769, 128)
#     (lstm): LSTM(128, 128)
#   )
#   (decoder): Decoder(
#     (embedding): Embedding(46365, 128)
#     (lstm): LSTM(128, 128)
#     (fc): Linear(in_features=128, out_features=46365, bias=True)
#     (softmax): LogSoftmax(dim=1)
#   )
# )

# %%
print("Type 'exit' to finish the chat.\n", "-"*50, '\n')
pair_list = []
while (True):
    pair = input("> ")
    
    if pair.strip() == "exit":
        break  
    pair_item = pair.split(",")
    for item in pair_item:
        pair_list.append(item)  

pair_list = [pair_list]
# Out:
# Type 'exit' to finish the chat.
#  --------------------------------------------------
#
# > who would she perform with at superbowl 50,coldplay
# > exit

# %%
evaluate(source, target, pair_list, seq2seq, len(pair_list[0][1]))
# Out:
# june era and nation coldplay of

# %%
pairs
# Out:
# [['to whom did the virgin mari alleg appear in 1858 in lourd franc',
#   'saint bernadett soubir'],
#  ['what is in front of the notr dame main build', 'a copper statu of christ'],
#  ['the basilica of the sacr heart at notr dame is besid to which structur',
#   'the main build'],
#  ['what is the grotto at notr dame', 'a marian place of prayer and reflect'],
#  ['what sit on top of the main build at notr dame',
#   'a golden statu of the virgin mari'],
#  ['when did the scholast magazin of notr dame begin publish', 'septemb 1876'],
#  ['how often is notr dame the juggler publish', 'twice'],
#  ['what is the daili student paper at notr dame call', 'the observ'],
#  ['how mani student news paper are found at notr dame', 'three'],
#  ['in what year did the student paper common sens begin public at notr dame',
#   '1987'],
#  ['where is the headquart of the congreg of the holi cross', 'rome'],
#  ['what is the primari seminari of the congreg of the holi cross',
#   'moreau seminari'],
#  ['what is the oldest structur at notr dame', 'old colleg'],
#  ['what individu live at fatima hous at notr dame',
#   'retir priest and brother'],
#  ['which prize did frederick buechner creat', 'buechner prize for preach'],
#  ['how mani bs level degre are offer in the colleg of engin at notr dame',
#   'eight'],
#  ['in what year was the colleg of engin at notr dame form', '1920'],
#  ['befor the creation of the colleg of engin similar studi were carri out at which notr dame colleg',
#   'the colleg of scienc'],
#  ['how mani depart are within the stinsonremick hall of engin', 'five'],
#  ['the colleg of scienc began to offer civil engin cours begin at what time at notr dame',
#   'the 1870s'],
#  ['what entiti provid help with the manag of time for new student at notr dame',
#   'learn resourc center'],
#  ['how mani colleg for undergradu are at notr dame', 'five'],
#  ['what was creat at notr dame in 1962 to assist first year student',
#   'the first year of studi program'],
#  ['which organ declar the first year of studi program at notr dame outstand',
#   'u s news world report'],
#  ['the grant of doctor degre first occur in what year at notr dame', '1924'],
#  ['what type of degre is an mdiv', 'master of divin'],
#  ['which program at notr dame offer a master of educ degre',
#   'allianc for cathol educ'],
#  ['in what year was a master of art cours first offer at notr dame', '1854'],
#  ['which depart at notr dame is the onli one to not offer a phd program',
#   'depart of pre profession studi'],
#  ['what institut at notr dame studi the reason for violent conflict',
#   'joan b kroc institut for intern peac studi'],
#  ['what is the titl of notr dame theodor hesburgh',
#   'presid emeritus of the univers of notr dame'],
#  ['in what year was the joan b kroc institut for intern peac studi found',
#   '1986'],
#  ['to whom was john b kroc marri', 'ray kroc'],
#  ['what compani did ray kroc own', 'mcdonald'],
#  ['how mani stori tall is the main librari at notr dame', '14'],
#  ['what is the name of the main librari at notr dame',
#   'theodor m hesburgh librari'],
#  ['in what year was the theodor m hesburgh librari at notr dame finish',
#   '1963'],
#  ['which artist creat the mural on the theodor m hesburgh librari',
#   'millard sheet'],
#  ['what is a common name to refer the mural creat by millard sheet at notr dame',
#   'touchdown jesus'],
#  ['how mani incom student did notr dame admit in fall 2015', '3 577'],
#  ['what percentag of student were admit to notr dame in fall 2015', '19 7'],
#  ['where doe notr dame rank in term of academ profil among research univers in the us',
#   'the top 10 to 15 in the nation'],
#  ['what percentag of student at notr dame particip in the earli action program',
#   '39 1'],
#  ['how mani mile doe the averag student at notr dame travel to studi there',
#   'more than 750 mile'],
#  ['where did us news world report rank notr dame in it 20152016 univers rank',
#   '18th overal'],
#  ['forbescom place notr dame at what posit compar to other us research univers',
#   '8th'],
#  ['the undergrad school at the mendoza colleg of busi was rank where accord to businessweek',
#   '1st overal'],
#  ['in 2014 what entiti name notr dame 10th best of all american univers',
#   'usa today'],
#  ['what percentag of notr dame student decid to studi abroad', '57 6'],
#  ['what person was the director of the scienc museum at notr dame in the late 19th centuri',
#   'father joseph carrier c s c'],
#  ['what was the lifespan of john augustin zahm', '1851 1921'],
#  ['what program did john augustin zahm come to codirect at nore dame',
#   'the scienc depart'],
#  ['what book did john zahm write in 1896', 'evolut and dogma'],
#  ['what professorship did father josh carrier hold at notr dame',
#   'professor of chemistri and physic'],
#  ['in what year did albert zahm begin compar aeronat model at notr dame',
#   '1882'],
#  ['which professor sent the first wireless messag in the usa',
#   'professor jerom green'],
#  ['in what year did jerom green send his first wireless messag',
#   'around 1899'],
#  ['which individu work on project at notr dame that eventu creat neopren',
#   'father julius nieuwland'],
#  ['what did the brother of john zahm construct at notr dame',
#   'an earli wind tunnel'],
#  ['work on a germfreelif end up in the creation of which notr dame institut',
#   'the lobund institut'],
#  ['around what time did lobund of notr dame becom independ', 'the 1940s'],
#  ['in what year did lobund at notr dame becom an institut', '1950'],
#  ['the lobund institut was merg into the depart of biolog at notr dame in what year',
#   '1958'],
#  ['when did studi of a germfreelif begin at notr dame', '1928'],
#  ['gurian creat what in 1939 at notr dame', 'the review of polit'],
#  ['what was the review of polit inspir by', 'german cathol journal'],
#  ['over how mani year did gurian edit the review of polit at notr dame', '44'],
#  ['thoma stritch was an editor of which publican from notr dame',
#   'review of polit'],
#  ['who was the presid of notr dame in 2012', 'john jenkin'],
#  ['the kellogg institut for intern studi is part of which univers',
#   'notr dame'],
#  ['what doe the kroc institut at notr dame focus on', 'intern peac studi'],
#  ['in what year did notr dame begin to host the global adapt index', '2013'],
#  ['what threat doe the global adapt index studi', 'climat chang'],
#  ['how mani undergrad were attend notr dame in 2014', '8 448'],
#  ['what percentag of student at notr dame are the children of former notr dame student',
#   '21 24'],
#  ['how mani team particip in the notr dame bookstor basketbal tournament',
#   'over 700'],
#  ['for what caus is money rais at the bengal bout tournament at notr dame',
#   'the holi cross mission in bangladesh'],
#  ['how mani student in total were at notr dame in 2014', '12 179'],
#  ['what percentag of undergrad live on the notr dame campus', '80'],
#  ['how mani student hous area are reserv for notr dame graduat student',
#   'four'],
#  ['how mani dorm for male are on the notr dame campus', '15'],
#  ['what amount of the graduat student bodi at notr dame live on the campus',
#   '20'],
#  ['there are how mani dorm for femal at notr dame', '14'],
#  ['what is congreg of holi cross in latin', 'congregatio a sancta cruce'],
#  ['what percentag of notr dame student feel they are christian',
#   'more than 93'],
#  ['how often is cathol mass held at notr dame in a week', 'over 100 time'],
#  ['how mani chapel are on the notr dame campus', 'fifty seven'],
#  ['what amount of the student bodi of notr dame identifi as cathol',
#   'over 80'],
#  ['what was the music hall at notr dame call', 'washington hall'],
#  ['in what year was the main build at notr dame raze in a fire', '1879'],
#  ['who was the presid of notr dame in 1879', 'rev william corbi'],
#  ['on what date was the rebuild of the main build begun at notr dame after the fire that claim the previous',
#   '17th of may'],
#  ['what did the scienc hall at notr dame come to be known as',
#   'lafortun student center'],
#  ['what type of educ was push at notr dame befor it embrac of nation standard',
#   'scholast and classic'],
#  ['which colleg did notr dame add in 1921', 'colleg of commerc'],
#  ['in 1919 a new presid of notr dame was name who was it', 'father jame burn'],
#  ['over how mani year did the chang to nation standard undertaken at notr dame in the earli 20th centuri take place',
#   'three year'],
#  ['those who attend a jesuit colleg may have been forbidden from join which law school due to the curricula at the jesuit institut',
#   'harvard law school'],
#  ['the notr dame footbal team got a new head coach in 1918 who was it',
#   'knute rockn'],
#  ['what was the amount of win knute rockn attain at notr dame while head coach',
#   '105'],
#  ['in what year did the team lead by knute rockn win the rose bowl', '1925'],
#  ['how mani year was knute rockn head coach at notr dame', '13'],
#  ['how mani nation titl were won when knute rockn coach at notr dame',
#   'three'],
#  ['cathol peopl identifi with notr dame what religi group did peopl feel yale repres',
#   'the protest establish'],
#  ['notr dame student had a showdown in 1924 with which anticathol group',
#   'the ku klux klan'],
#  ['which colleg presid of notr dame is credit with prevent more confront between student and the kkk',
#   'fr matthew walsh'],
#  ['what type of event did the klan intend to have at notr dame in march of 1924',
#   'a week long klavern'],
#  ['where did notr dame student and the kkk have their encount', 'south bend'],
#  ['which person becam vicepresid of notr dame in 1933',
#   'father john franci o hara'],
#  ['who was the presid of notr dame in 1934', 'father john franci o hara'],
#  ['irvin abel was given what award by notr dame', 'laetar medal'],
#  ['which year was the laetar medal first given out at notr dame', '1883'],
#  ['for whos glori did father ohara believ that the notr dame footbal team play',
#   'god'],
#  ['around the time that rev cavanaugh becam presid of notr dame by how much did the undergrad student bodi of notr dame increas',
#   'more than half'],
#  ['which institut involv anim life did cavanaugh creat at notr dame',
#   'lobund institut for anim studi'],
#  ['what is oshaughnessi hall of notr dame former known as',
#   'hall of liber art'],
#  ['which presid did notr dame have in 1947', 'rev john j cavanaugh c s c'],
#  ['outsid of an institut studi anim what other institut did cavanugh creat at notr dame',
#   'mediev institut'],
#  ['what was the lifespan of theodor hesburgh', '1917 2015'],
#  ['in the time that hesburgh was presid of notr dame by what factor did the oper budget increas',
#   '18'],
#  ['what was the size of the notr dame endow when theodor hesburgh becam presid',
#   '9 million'],
#  ['dure what year was theodor hesburgh presid of notr dame', '1952 87'],
#  ['how mani faculti member were at notr dame when hesburgh left the role of presid',
#   '950'],
#  ['what type of educ institut is hesburgh given credit for creat at notr dame',
#   'coeduc'],
#  ['which role did charl sheedi have at notr dame', 'dean of art and letter'],
#  ['what titl did thoma blantz have at notr dame',
#   'vice presid of student affair'],
#  ['in what year did notr dame have it earliest undergradu that was femal',
#   '1971'],
#  ['with what institut did notr dame agre to an exchang program in the 1960s',
#   'saint mari colleg'],
#  ['dure what year was edward malloy presid of notr dame', '1987 2005'],
#  ['what was the sat score on averag at notr dame when edward malloy becam presid',
#   '1240'],
#  ['when malloy becam presid of notr dame what was the size of the endow',
#   '350 million'],
#  ['when malloy reach the end of his time as presid how much annual fund for research did notr dame have',
#   'more than 70 million'],
#  ['the amount of professor at notr dame increas by what amount under malloy',
#   '500'],
#  ['when did john jenkin becom the presid of notr dame', '2005'],
#  ['in term of the amount of presid notr dame has had where is john jenkin on the list',
#   '17th'],
#  ['who was the notr dame presid that preced john jenkin', 'malloy'],
#  ['which arena was construct under jenkin at notr dame',
#   'compton famili ice arena'],
#  ['how much money was spent on enhanc notr dame stadium under john jenkin',
#   '400m'],
#  ['which congreg is in charg of the old colleg at notr dame',
#   'congreg of holi cross'],
#  ['what structur is found on the locat of the origin church of father sorin at notr dame',
#   'basilica of the sacr heart'],
#  ['in which architectur style is the basilica of the sacr heart at notr dame made',
#   'french reviv'],
#  ['which individu paint the insid of the basilica of the sacr heart at notr dame',
#   'luigi gregori'],
#  ['in what year was the grotto of our ladi of lourd at notr dame construct',
#   '1896'],
#  ['which person oversaw the creation of a scienc hall at notr dame in 1883',
#   'fr zahm'],
#  ['in what year did the student union build at notr dame get renam to lafortun center',
#   '1950'],
#  ['after which individu was the lafortun center notr dame name',
#   'joseph lafortun'],
#  ['how larg in squar feet is the lafortun center at notr dame',
#   '83 000 squar feet'],
#  ['what is the annual budget of notr dame lafortun center', '1 2 million'],
#  ['how mani hall are at notr dame that hous student', '29'],
#  ['which librari was built at notr dame in 1963', 'theodor hesburgh librari'],
#  ['how mani book are hous at the theodor hesburgh librari',
#   'almost 4 million'],
#  ['construct for which hall start on march 8th 2007 at notr dame',
#   'duncan hall'],
#  ['which basebal stadium is found at notr dame', 'frank eck stadium'],
#  ['in what year did notr dame creat the offic of sustain', '2008'],
#  ['what percentag of the food serv at notr dame is local grown', '40'],
#  ['notr dame got a b for it sustain practic from which entiti',
#   'sustain endow institut'],
#  ['gustavo gutierrez is faculti of which institut',
#   'kroc institut for intern peac studi'],
#  ['in what year did notr dame first have a facil in england', '1968'],
#  ['at which locat is the london center oper by notr dame found',
#   '1 suffolk street in trafalgar squar'],
#  ['notr dame has a center in beij what is it refer to as', 'global gateway'],
#  ['in what year did the suffolk street locat start to hous a notr dame facil',
#   '1998'],
#  ['what was notr dame first colleg', 'the colleg of art and letter'],
#  ['in what year was the the colleg of art and letter at notr dame creat',
#   '1842'],
#  ['in what year did the colleg of art and letter at notr dame grant it first degre',
#   '1849'],
#  ['on which univers did notr dame base it curriculum on',
#   'saint loui univers'],
#  ['how mani ba major doe the colleg of art and letter at notr dame offer',
#   '33'],
#  ['which presid at notr dame creat the colleg of scienc',
#   'father patrick dillon'],
#  ['in what year was the notr dame colleg of scienc form', '1865'],
#  ['how mani year long was a scientif cours under patrick dillon at notr dame',
#   'six year'],
#  ['which hall at notr dame contain the current colleg of scienc',
#   'jordan hall of scienc'],
#  ['how mani undergrad student attend the colleg of scienc at notr dame today',
#   'over 1 200'],
#  ['in 1899 notr dame form which colleg', 'school of architectur'],
#  ['in what build is the current school of architectur hous at notr dame',
#   'bond hall'],
#  ['what length is the cours of studi at the notr dame school of architectur',
#   'five year'],
#  ['in which locat do student of the school of architectur of notr dame spend their 3rd year',
#   'rome'],
#  ['which prestigi prize doe the school of architectur at notr dame give out',
#   'driehaus architectur prize'],
#  ['in what year did the open of a theolog librari at notr dame occur', '2015'],
#  ['where is the theolog librari at notr dame',
#   'the first floor of stanford hall'],
#  ['how mani book are held by the notr dame librari',
#   'over three million volum'],
#  ['current where doe notr dame librari rank in the nation',
#   'one of the 100 largest'],
#  ['what caus mani intellectu cathol to leav europ in the 1930s',
#   'the rise of hitler and other dictat'],
#  ['from where did antonhermann chroust come to reach notr dame', 'germani'],
#  ['what field of studi did antonhermann chroust special in',
#   'classic and law'],
#  ['who did waldemar gurian receiv his tutelag under while seek his doctor',
#   'max scheler'],
#  ['what was ivan meštrović known for be', 'a renown sculptor'],
#  ['the school known as notr dame is known by a more lengthi name what is it',
#   'univers of notr dame du'],
#  ['what type of institut is the notr dame', 'cathol research univers'],
#  ['the french word notr dame du lac translat to what in english',
#   'our ladi of the lake'],
#  ['who is the patron saint of notr dame', 'the virgin mari'],
#  ['how larg is notr dame in acr', '1 250'],
#  ['what caus notr dame to becom notabl in the earli 20th centuri',
#   'it fight irish footbal team'],
#  ['which 20th centuri notr dame footbal coach is most notabl', 'knute rockn'],
#  ['which athlet associ are the student athlet at notr dame a part of',
#   'ncaa divis i'],
#  ['how mani student at notr dame receiv the heisman trophi', 'seven'],
#  ['there were multipl student from notr dame who enter the pro footbal hall of fame how mani',
#   '13'],
#  ['where among us univers doe notr dame rank', 'among the top twenti'],
#  ['how mani individu colleg are part of notr dame', 'four'],
#  ['which prize doe the architectur school at notr dame give out',
#   'driehaus architectur prize'],
#  ['how mani doctor and master program are avail at notr dame', 'more than 50'],
#  ['which art museum doe notr dame administ', 'snite museum of art'],
#  ['in what year was father edward sorin given two year to creat a colleg',
#   '1842'],
#  ['which individu offer land to father edward sorin',
#   'célestin guynem de la hailandièr'],
#  ['which church was father edward sorin repres',
#   'the congreg of the holi cross'],
#  ['on what date did brother from holi cross arriv at the futur locat of notr dame',
#   'novemb 26 1842'],
#  ['which structur was the first use for the purpos of the colleg',
#   'father stephen badin old log chapel'],
#  ['in what year did the initi degre get hand out at notr dame', '1849'],
#  ['in what year did the origin sorin built main build get replac', '1865'],
#  ['which individu began a librari at notr dame', 'father lemonni'],
#  ['in what year had the librari at notr dame reach 10000 book', '1879'],
#  ['in what year was the librari at notr dame start', '1873'],
#  ['which televis station find it home at notr dame', 'ndtv'],
#  ['how mani program did ndtv featur in 2002', 'one show'],
#  ['which radio station provid radio to the student of notr dame at 889 fm',
#   'wsnd fm'],
#  ['which internet radio station of notr dame is serv as an internet stream',
#   'wvfi'],
#  ['how much is eddi street common at notr dame expect to cost', '215 million'],
#  ['when was ground broke on the eddi street common project of notr dame',
#   'june 3 2008'],
#  ['who is the develop of eddi street common', 'kite realti'],
#  ['which entiti did notr dame hire to build a park structur outsid of eddi street common',
#   'the citi of south bend'],
#  ['there were protest as a part of the construct at eddi street common they came due tot he hire of whom',
#   'non union worker'],
#  ['what doe the acronym ncaa stand for', 'nation collegi athlet associ'],
#  ['which leagu did notr dame fight irish team particip in in 1982',
#   'horizon leagu'],
#  ['what when confer do the notr dame fenc team take part in',
#   'midwest fenc confer'],
#  ['there is a confer that the male hockey team of notr dame compet in what is it',
#   'hockey east'],
#  ['in what confer did the fight irish take part in in 2012',
#   'big east confer'],
#  ['to what confer did the fight irish go after the big east', 'the acc'],
#  ['how mani team in each season do the fight irish commit to play against acc oppon',
#   'five'],
#  ['where did the fight irish hockey team compet prior to a move to hockey east in term of confer',
#   'central collegi hockey associ'],
#  ['what color are the offici one use by notr dame in sport competit',
#   'navi blue and gold rush'],
#  ['what type of mascot do the notr dame sport team have', 'leprechaun'],
#  ['who current provid uniform to notr dame sport team', 'under armour'],
#  ['what is the valu of the contract between under armour and notr dame',
#   'almost 100 million'],
#  ['when did the notr dame march band form', '1846'],
#  ['what is notabl about the notr dame march band',
#   'oldest univers band in continu exist in the unit state'],
#  ['what is the notr dame fight song', 'notr dame victori march'],
#  ['which team did notr dame footbal team find inspir from',
#   'michigan wolverin footbal team'],
#  ['in what year did notr dame footbal begin', '1887'],
#  ['what univers is notr dame tie with in term of most heisman trophi winner',
#   'ohio state univers'],
#  ['against which team doe notr dame compet for the jewel shillelagh', 'usc'],
#  ['in term of notr dame student in the colleg footbal hall of fame the amount of student name is what',
#   'the most'],
#  ['what notabl footbal player play at notr dame from 1916 to 1920',
#   'georg gipp'],
#  ['against which oppon did knute rockn tell his team to win one for the gipper',
#   'the armi team'],
#  ['which person portray knute rockn in the 1940 movi knute rockn',
#   'pat o brien'],
#  ['ronald reagan play the role of whom in 1940s knute rockn', 'gipp'],
#  ['how mani seat are in notr dame stadium', '80 795'],
#  ['what is display at zahm hous for footbal home game at notr dame',
#   'two stori banner'],
#  ['what occur at midnight preced a footbal home game at notr dame',
#   'the drummer circl'],
#  ['from where doe the band of the fight irish lead a march to the notr dame stadium for footbal home game',
#   'the step of bond hall'],
#  ['what song doe the trumpet section of the band of the fight irish play preced home footbal game',
#   'the notr dame victori march and the notr dame alma mater'],
#  ['on what day do notr dame home footbal game occur', 'saturday'],
#  ['how mani win doe the notr dame men basketbal team have', 'over 1 600'],
#  ['how mani school have a similar men basketbal record to notr dame in term of win',
#   '12'],
#  ['how mani ncaa tournament did the notr dame men basketbal team take part in',
#   '28'],
#  ['which notr dame men basketbal player has the record for more point in one game',
#   'austin carr'],
#  ['who was the notr dame men basketbal coach in 2014', 'mike brey'],
#  ['who wrote the origin lyric to the notr dame victori march', 'john f shea'],
#  ['in what year did michael j shea graduat from notr dame', '1904'],
#  ['who is respons for write the music for notr dame victori march',
#   'rev michael j shea'],
#  ['in what year did notr dame victori march get copyright', '1928'],
#  ['to where are the loyal son in notr dame fight song march',
#   'onward to victori'],
#  ['ronald reagan had a nicknam what was it', 'the gipper'],
#  ['in what film did a parodi of the win one for the gipper speech appear',
#   'airplane'],
#  ['who star as daniel ruettig in the film rudi', 'sean astin'],
#  ['which person was a former comrad to ted striker in the film airplan',
#   'georg zipp'],
#  ['pat obrien portray which person in the film knute rockn', 'knute rockn'],
#  ['which secretari of state attend notr dame', 'condoleezza rice'],
#  ['which notr dame alum from the colleg of scienc won a nobel prize',
#   'eric f wieschaus'],
#  ['who is the current presid of notr dame', 'rev john jenkin'],
#  ['mariel zaguni is notabl for win what', 'olymp gold'],
#  ['which notabl astronaut is known to have attend notr dame', 'jim wetherbe'],
#  ['when did beyonc start becom popular', 'in the late 1990s'],
#  ['what area did beyonc compet in when she was grow up', 'sing and danc'],
#  ['when did beyonc leav destini child and becom a solo singer', '2003'],
#  ['in what citi and state did beyonc grow up', 'houston texa'],
#  ['in which decad did beyonc becom famous', 'late 1990s'],
#  ['in what rb group was she the lead singer', 'destini child'],
#  ['what album made her a worldwid known artist', 'danger in love'],
#  ['who manag the destini child group', 'mathew knowl'],
#  ['in what citi did beyonc grow up', 'houston'],
#  ['what was the name of beyonc first solo album', 'danger in love'],
#  ['on what date was beyonc born', 'septemb 4 1981'],
#  ['what is beyonc full name', 'beyoncé gisell knowles cart'],
#  ['when did beyoncé rise to fame', 'late 1990s'],
#  ['what role did beyoncé have in destini child', 'lead singer'],
#  ['what was the first album beyoncé releas as a solo artist',
#   'danger in love'],
#  ['when did beyoncé releas danger in love', '2003'],
#  ['how mani grammi award did beyoncé win for her first solo album', 'five'],
#  ['what was beyoncé role in destini child', 'lead singer'],
#  ['what was the name of beyoncé first solo album', 'danger in love'],
#  ['when did beyoncé releas her first solo album', '2003'],
#  ['after her second solo album what other entertain ventur did beyonc explor',
#   'act'],
#  ['which artist did beyonc marri', 'jay z'],
#  ['to set the record for grammi how mani did beyonc win', 'six'],
#  ['for what movi did beyonc receiv her first golden globe nomin', 'dreamgirl'],
#  ['when did beyonc take a hiatus in her career and take control of her manag',
#   '2010'],
#  ['which album was darker in tone from her previous work', 'beyoncé'],
#  ['after what movi portray etta jame did beyonc creat sasha fierc',
#   'cadillac record'],
#  ['when did destini child end their group act', 'june 2005'],
#  ['what was the name of beyoncé second solo album', 'b day'],
#  ['what was beyoncé first act job in 2006', 'dreamgirl'],
#  ['who is beyoncé marri to', 'jay z'],
#  ['what is the name of beyoncé alterego', 'sasha fierc'],
#  ['in her music what are some recur element in them',
#   'love relationships and monogami'],
#  ['time magazin name her one of the most 100 what peopl of the centuri',
#   'influenti'],
#  ['which magazin declar her the most domin woman musician', 'forb'],
#  ['in which decad did the record industri associ of america recogn beyonc as the the top certifi artist',
#   '2000s'],
#  ['what magazin rate beyonc as the most power femal musician in 2015', 'forb'],
#  ['how did beyonc describ herself as a feminist', 'modern day feminist'],
#  ['in which year did time rate beyonc in the 100 most influenti peopl in the world',
#   '2013 and 2014'],
#  ['how mani record has beyonc sold in her 19 year career', '118 million'],
#  ['how mani record did beyoncé sell as part of destini child', '60 million'],
#  ['after leav destini child how mani record did beyoncé releas under her own name',
#   '118 million'],
#  ['how mani grammi award has beyoncé won', '20'],
#  ['what magazin name beyoncé as the most power femal musician for 2015',
#   'forb'],
#  ['beyonc younger sibl also sang with her in what band', 'destini child'],
#  ['where did beyonc get her name from', 'her mother maiden name'],
#  ['what race was beyonc father', 'african american'],
#  ['beyonc childhood home believ in what religion', 'methodist'],
#  ['beyonc father work as a sale manag for what compani', 'xerox'],
#  ['beyonc mother work in what industri', 'hairdress and salon owner'],
#  ['what younger sister of beyonc also appear in destini child', 'solang'],
#  ['beyonc is a descend of what arcadian leader', 'joseph broussard'],
#  ['what compani did beyoncé father work for when she was a child', 'xerox'],
#  ['what did beyoncé mother own when beyoncé was a child', 'salon'],
#  ['what is the name of beyoncé younger sister', 'solang'],
#  ['beyoncé is a descend of which acadian leader', 'joseph broussard'],
#  ['beyoncé was rais in what religion', 'methodist'],
#  ['what town did beyonc go to school in', 'fredericksburg'],
#  ['who was the first person to notic beyonc sing abil', 'darlett johnson'],
#  ['beyonc move to which town after she left her first elementari school',
#   'houston'],
#  ['which of her teacher discov beyonc music talent',
#   'danc instructor darlett johnson'],
#  ['i which church was beyonc a member and soloist in the choir',
#   'st john unit methodist church'],
#  ['what type of school was parker elementari school', 'music magnet school'],
#  ['which song did beyonc sing to win a competit at age 7', 'imagin'],
#  ['what citi was beyoncé elementari school locat in', 'fredericksburg'],
#  ['what was the name of beyoncé first danc instructor', 'darlett johnson'],
#  ['how old was beyoncé when she won a school talent show', 'seven'],
#  ['what choir did beyoncé sing in for two year',
#   'st john unit methodist church'],
#  ['who decid to place beyonc group in star search the talent show',
#   'arn frager'],
#  ['in 1995 who decid to manag the girl sing group', 'beyoncé father'],
#  ['who was the first record label to give the girl a record deal',
#   'elektra record'],
#  ['who brought beyonc to california and enter her group in star search',
#   'arn frager'],
#  ['in what year did beyonc father quit his job to manag her group', '1995'],
#  ['what larg record compani record beyonc group first album', 'soni music'],
#  ['what record compani first sign beyonc group and later cut them',
#   'elektra record'],
#  ['at what age did beyonc meet latavia robertson', 'age eight'],
#  ['how old was beyoncé when she met latavia roberson', 'eight'],
#  ['what was the name of the first group beyoncé was a part of', 'girl tyme'],
#  ['who place girl tyme in star search', 'arn frager'],
#  ['when did beyoncé begin to manag the girl group', '1995'],
#  ['who sign the girl group on octob 5 1995',
#   'dwayn wiggin grass root entertain'],
#  ['which film featur destini child first major singl', 'men in black'],
#  ['for which song did destini child take home the grammi award for best rb perform',
#   'say my name'],
#  ['who did beyonc record with for the movi the best man', 'marc nelson'],
#  ['beyonc group chang their name to destini child in what year', '1996'],
#  ['the name destini child was base on a quot in which book of the bibl',
#   'book of isaiah'],
#  ['debut song kill time was featur on what movi sound track', 'men in black'],
#  ['what song won best rb perform in the 43 annual grammi award',
#   'say my name'],
#  ['what singer did beyonc record a song with for the movi the best man',
#   'marc nelson'],
#  ['where did destini child get their name from', 'book of isaiah'],
#  ['destini child song kill time was includ in which film soundtrack',
#   'men in black'],
#  ['what was destini child first major song hit', 'no no no'],
#  ['when did destini child releas their second album', '1999'],
#  ['who did beyoncé sing a duet with for the best man film', 'marc nelson'],
#  ['what mental health issu did beyonc go through', 'depress'],
#  ['what event occur after she was public critic', 'boyfriend left her'],
#  ['who support beyonc through her depress', 'her mother'],
#  ['what event caus beyonc depress', 'split with luckett and rober'],
#  ['how long was beyonc depress', 'a coupl of year'],
#  ['who help beyonc fight her depress the most', 'her mother'],
#  ['who replac luckett and roberson in destini child',
#   'farrah franklin and michell williams'],
#  ['who was blame for luckett and roberson leav destini child', 'beyoncé'],
#  ['who help beyoncé overcom her depress dure the year follow the destini child split',
#   'her mother'],
#  ['which newest member was remov from destini child', 'farrah franklin'],
#  ['char angel featur which singl from the band member',
#   'independ women part i'],
#  ['how mani week did their singl independ women part i stay on top', 'eleven'],
#  ['for what network did beyonc land a major movi role in', 'mtv'],
#  ['their third album survivor sold how mani dure it first week',
#   '663 000 copi'],
#  ['what french compos wrote the origin opera carmen in the 19th centuri',
#   'georg bizet'],
#  ['what album caus a lawsuit to be file in 2001', 'survivor'],
#  ['independ women part i was on which 2000 film soundtrack', 'charli angels'],
#  ['which film did beyoncé star in 2001 with mekhi phifer',
#   'carmen a hip hopera'],
#  ['what was the name of destini child third album', 'survivor'],
#  ['who file a lawsuit over survivor', 'luckett and roberson'],
#  ['when did destini child announc their hiatus', 'octob 2001'],
#  ['who did beyonc star with in the movi austin power in goldmemb',
#   'mike myer'],
#  ['which three countri did beyonc song work it out achiev top ten status',
#   'uk norway and belgium'],
#  ['beyonc star with cuba good jr in which film', 'the fight temptat'],
#  ['who did beyonc record the lead singl with in the movi the fight temptat',
#   'missi elliott'],
#  ['which other song from the soundtrack did better in the chart', 'summertim'],
#  ['what film did beyonc appear in with mike myer', 'austin power in goldmemb'],
#  ['what larg amount did the movi goldmemb gross', '73 million'],
#  ['what genr of movi did beyonc star in with cuba good jr', 'music comedi'],
#  ['what song was the lead singl from the film sound track', 'fight temptat'],
#  ['how did the critic view the movi the fight temptat', 'mix review'],
#  ['what film did beyoncé star in with mike myer in 2002',
#   'austin power in goldmemb'],
#  ['what was beyoncé charact call in austin power in goldmemb',
#   'foxxi cleopatra'],
#  ['which song did beyoncé releas as the lead singl for austin power in goldmemb soundtrack',
#   'work it out'],
#  ['what music comedi did beyoncé star in along with cuba good jr in 2003',
#   'the fight temptat'],
#  ['what song did beyoncé releas as the lead singl from the fight tempat',
#   'fight temptat'],
#  ['what was the highest beyonc first solo record achiev in the billboard hot 100',
#   'number four'],
#  ['beyonc first album by herself was call what', 'danger in love'],
#  ['how mani has danger in love sould worldwid sinc it debut', '11 million'],
#  ['beyonc first number one song was which song', 'crazi in love'],
#  ['how mani top five singl came from her first album', 'four'],
#  ['beyonc first solo album in the us with what artist in the lead singl',
#   'jay z'],
#  ['what solo album did beyonc releas in 2003', 'danger in love'],
#  ['the album danger in love achiev what spot on the billboard top 100 chart',
#   'number four'],
#  ['the closer i get to you was record with which artist', 'luther vandross'],
#  ['which artist was associ with beyoncé premier solo record', 'jay z'],
#  ['when did beyoncé releas her first solo album', 'june 24 2003'],
#  ['what is the lead singl on beyoncé first album', 'crazi in love'],
#  ['who help beyoncé earn a grammi award for best rb perform by a duo or group at the 46th annual grammi award',
#   'luther vandross'],
#  ['how mani award did beyoncé win at the 46th grammi award', 'five'],
#  ['destini child final album was name what', 'destini fulfil'],
#  ['destini child got a star on the hollywood walk of fame in what year',
#   '2006'],
#  ['in what year did beyonc embark on her danger in love tour of europ',
#   'novemb 2003'],
#  ['what was the name of the final album of destini child', 'destini fulfil'],
#  ['it was announc that destini child would disban in what european citi',
#   'barcelona'],
#  ['when did destini child get their star on the hollywood walk of fame',
#   'march 2006'],
#  ['what was the name of beyoncé european start that start in novemb 2003',
#   'danger in love tour'],
#  ['who did beyoncé tour with for the verizon lade first tour',
#   'missi elliott and alicia key'],
#  ['what major event did beyoncé perform at on februari 1 2004',
#   'super bowl xxxviii'],
#  ['what is the name of the final studio album from destini child',
#   'destini fulfilled'],
#  ['how mani album did beyonc sell in the first week when she releas her second album',
#   '541 000'],
#  ['the lead singl from the album was which song', 'déjà vu'],
#  ['how mani countri did her song irreplac get number one status in', 'five'],
#  ['how mani singl did her second album produc', 'five'],
#  ['what birthday did beyonc album bday celebr', 'twenty fifth birthday'],
#  ['what artist did beyonc duet with in the singl deja vu', 'jay z'],
#  ['how high did deja vu climb on the billboard chart', 'top five'],
#  ['what is the name of beyoncé second album', 'b day'],
#  ['how mani copi did bday sell dure the first week of it releas', '541 000'],
#  ['who collabor with beyoncé on the singl deja vu', 'jay z'],
#  ['which singl from bday was onli releas in the uk', 'green light'],
#  ['what movi did beyonc act in 2006', 'the pink panther'],
#  ['her second movi beyonc did was what film', 'dreamgirl'],
#  ['the singl listen was featur in which movi', 'dreamgirl'],
#  ['beyonc first world tour was when', '2007'],
#  ['how much money did beyonc tour make in 2007', '24 million'],
#  ['how mani million of dollar did the pink panther gross worldwid',
#   '158 8 million'],
#  ['what did beyonc call her first concert tour', 'the beyoncé experi'],
#  ['who was beyonc duet with in beauti liar', 'shakira'],
#  ['which film did beyoncé star with steve martin in', 'the pink panther'],
#  ['beyoncé role in dreamgirl was base on what pop singer', 'diana ross'],
#  ['what was the lead singl for the dreamgirl soundtrack', 'listen'],
#  ['what was the name of beyoncé first intern tour', 'the beyoncé experi'],
#  ['what pop singer did a duet with beyoncé on beauti liar', 'shakira'],
#  ['beyonc got marri in 2008 to whom', 'jay z'],
#  ['her third album i amsasha fierc was releas when', 'novemb 18 2008'],
#  ['for which decad did beyonc have more top ten song than ani other woman',
#   '2000s'],
#  ['which singer beat out beyonc for best video perform', 'taylor swift'],
#  ['in 2009 beyonc start her second world tour and gross how much money',
#   '119 5 million'],
#  ['how did she reveal the marriag', 'in a video montag'],
#  ['when did beyonc begin her second world tour', 'march 2009'],
#  ['who beat out beyonc for best femal video', 'taylor swift'],
#  ['how much did the second world tour make in dollar', '119 5 million'],
#  ['when did beyoncé get marri', 'april 4 2008'],
#  ['who did beyoncé marri', 'jay z'],
#  ['who is beyoncé alter ego', 'sasha fierc'],
#  ['the video for what song won beyoncé the 2009 mtv video of the year award',
#   'singl ladi'],
#  ['which promin star felt the 2009 femal video of the year award should have went to beyoncé instead of taylor swift',
#   'kany west'],
#  ['beyonc portray which charact in the film cadillac record', 'etta jame'],
#  ['beyonc gave her entir salari from cadillac record to which organ',
#   'phoenix hous'],
#  ['which song did beyonc sing at the first coupl inaugur ball', 'at last'],
#  ['what genr of film was the movi obsess in which beyonc star in', 'thriller'],
#  ['a fight scene from the movi obsess won which award for beyonc',
#   'mtv movi award for best fight'],
#  ['where did beyonc donat her salari from the movi cadillac record',
#   'phoenix hous'],
#  ['what thriller film did beyonc star in', 'obsess'],
#  ['what was the name of the woman she play in obsess', 'sharon charl'],
#  ['how much more that the buget did the film gross', '60 million'],
#  ['which singer did beyoncé portray in cadillac record', 'etta jame'],
#  ['which organ receiv beyoncé entir cadillac record salari', 'phoenix hous'],
#  ['where did beyoncé perform on januari 20 2009',
#   'the first coupl first inaugur ball'],
#  ['which thriller film did beyoncé star in with ali larter', 'obsessed'],
#  ['how mani award was beyonc nomin for at the 52nd grammi award', 'ten'],
#  ['beyonc tie with which artist for most nomin by a femal artist',
#   'lauryn hill'],
#  ['in 2010 beyonc work with which other famous singer', 'ladi gaga'],
#  ['how mani number one singl did beyonc now have after the song telephon',
#   'six'],
#  ['beyonc tie who for most number one singl by a femal', 'mariah carey'],
#  ['beyonc receiv how mani nomin at the 52nd annual grammi award', 'ten nomin'],
#  ['what song was the sixth first place song for beyonc', 'telephon'],
#  ['who els appear with beyonc in telephon', 'ladi gaga'],
#  ['who did they tie with for six top song', 'mariah carey'],
#  ['who did beyonc tie with for the most nomin in a year', 'lauryn hill'],
#  ['how mani nomin did beyoncé receiv at the 52nd grammi award ceremoni',
#   'ten'],
#  ['who did beyoncé tie with for the most grammi nomin for femal artist',
#   'lauryn hill'],
#  ['beyoncé was a featur artist on which singer hit telephon', 'ladi gaga'],
#  ['who did beyoncé and ladi gaga tie with for the most number one hit sinc 1992',
#   'mariah carey'],
#  ['beyonc would take a break from music in which year', '2010'],
#  ['which year did beyonc and her father part busi way', '2010'],
#  ['which famous landmark did beyonc see in china', 'the great wall of china'],
#  ['in what year did beyonc have her hiatus', '2010'],
#  ['who inspir this hiatus', 'her mother'],
#  ['when did she stop use her father as a manag', 'dure the break'],
#  ['how long did the hiatus last', 'nine month'],
#  ['what did beyoncé announc in januari 2010', 'a hiatus'],
#  ['who suggest the hiatus for beyoncé', 'her mother'],
#  ['who did beyoncé part way with dure her hiatus', 'her father'],
#  ['how long did her hiatus last', 'nine month'],
#  ['in which year was report about beyonc perform for muammar gaddafi surfac',
#   '2011'],
#  ['who did beyonc donat the money to earn from her show',
#   'clinton bush haiti fund'],
#  ['beyonc becam the first femal artist to perform solo in 20 year at which stage',
#   'the 2011 glastonburi festiv'],
#  ['which organ did beyonc spokespeopl confirm her donat to',
#   'the huffington post'],
#  ['beyonc was list in 2011 as the highest paid perform per what', 'minut'],
#  ['hoe did everyon learn that beyonc perform for kaddafi',
#   'document obtain by wikileak'],
#  ['when did this leak happen', '2011'],
#  ['who did she tell about the donat', 'the huffington post'],
#  ['where did beyonc perform in 2011', 'glastonburi festiv'],
#  ['who did beyoncé perform privat for in 2011', 'muammar gaddafi'],
#  ['who releas the inform about beyoncé perform for the libyan ruler',
#   'wikileak'],
#  ['which organ did beyoncé donat her pay for the privat perform to',
#   'clinton bush haiti fund'],
#  ['beyoncé was the first femal singer to headlin what at the 2011 glastonburi festiv',
#   'pyramid stage'],
#  ['beyonc fourth album debut in what year', '2011'],
#  ['which singl had the most success from that album', 'love on top'],
#  ['beyonc won an award for which activ in 2011', 'write'],
#  ['in 2011 beyonc perform for four night where', 'new york roseland ballroom'],
#  ['when was beyonc forth album releas', 'june 28 2011'],
#  ['how mani copi did the album sell in it first week', '310 000 copi'],
#  ['who award beyonc and award for write',
#   'new york associ of black journalist'],
#  ['when did she perform at the roseland ballroom', '2011'],
#  ['what is the name of beyoncé fourth studio album', '4'],
#  ['when was 4 releas', 'june 28 2011'],
#  ['how mani copi of 4 sold in the first week', '310 000'],
#  ['what magazin did beyoncé write a stori for about her earlier hiatus',
#   'essenc'],
#  ['where did beyoncé perform for four night of stand room onli concert in 2011',
#   'new york roseland ballroom'],
#  ['when did beyonc have her first child', 'januari 7 2012'],
#  ['where did beyonc give birth to her first child', 'lenox hill hospit'],
#  ['beyonc first child is name what', 'blue ivi carter'],
#  ['her first appear perform sinc give birth was where',
#   'revel atlant citi ovat hall'],
#  ['when did beyonc have her first child', 'januari 7 2012'],
#  ['what was the child name', 'blue ivi carter'],
#  ['how long was it after the birth of her child befor she perform again',
#   'five month'],
#  ['how mani night did she perform at atlant citi', 'four night'],
#  ['when did beyoncé give birth to a daughter', 'januari 7 2012'],
#  ['what did beyoncé name her daughter', 'blue ivi carter'],
#  ['where was blue ivi born', 'lenox hill hospit in new york'],
#  ['where was beyoncé first public perform after give birth',
#   'revel atlant citi ovat hall'],
#  ['how mani night did beyoncé play at the resort', 'four'],
#  ['destini child releas a compil album about which topic', 'romanc'],
#  ['beyonc documentari movi was call what', 'life is but a dream'],
#  ['what did beyonc sign in 2013', 'global publish agreement'],
#  ['when did destini child releas it album love song', 'januari 2013'],
#  ['what was the titl of the ad track in love song', 'nuclear'],
#  ['at whose inaugur did she perform the nation anthem', 'presid obama'],
#  ['how mani tweet per minut did the half time show get',
#   '268 000 tweet per minut'],
#  ['when did destini child releas love song', 'januari 2013'],
#  ['what was the new track for love song', 'nuclear'],
#  ['what did beyoncé sing at presid obama second inaugur',
#   'the american nation anthem'],
#  ['what event did beyoncé perform at one month after obama inaugur',
#   'super bowl xlvii halftim show'],
#  ['what is the name of beyoncé documentari film', 'life is but a dream'],
#  ['how mani date did beyonc the mrs carter show entail', '132'],
#  ['one of beyonc most success tour yet was which one', 'the mrs carter show'],
#  ['beyonc wrote which song for the movi epic', 'rise up'],
#  ['beyonc voic a charact in which anim film', 'epic'],
#  ['when did the tour begin', 'april 15'],
#  ['of what event was beyonc honorari chair', '2013 met gala'],
#  ['what part did she voic for the movi epic', 'queen tara'],
#  ['what song did beyonc record for the film epic', 'rise up'],
#  ['what was the name of beyoncé tour that she start on april 15',
#   'the mrs carter show world tour'],
#  ['how mani date did the mrs carter show world tour have', '132'],
#  ['which ami winehous song did beyoncé cover and releas in may 2014',
#   'back to black'],
#  ['beyoncé was an honorari chair of the 2013 what', 'met gala'],
#  ['which charact in the film epic was voic by beyoncé', 'queen tara'],
#  ['where did beyonc releas her 5th album to a huge surpris', 'the itun store'],
#  ['when did beyonc get her fifth consecut number one hit album',
#   'decemb 13 2013'],
#  ['where was the album releas', 'the itun store'],
#  ['who join beyonc on her on the run tour', 'jay z'],
#  ['who report beyonc to e the top earn woman in music', 'forb'],
#  ['how much more were her earn that the year befor',
#   'more than doubl her earn'],
#  ['when did beyoncé releas her fifth studio album', 'decemb 13 2013'],
#  ['how mani digit copi of her fifth album did beyoncé sell in six day',
#   'one million'],
#  ['what song on beyoncé fifth studio album featur her husband',
#   'drunk in love'],
#  ['what was the name of the tour featur both beyoncé and jay z',
#   'on the run tour'],
#  ['how mani award did beyonc take home with her at the 57th grammi award',
#   'three'],
#  ['which artist beat beyonc out for album of the year', 'beck'],
#  ['which magazin did beyonc pose on the cover for in august of 2015', 'vogu'],
#  ['beyonc would perform with who at superbowl 50', 'coldplay'],
#  ['beyonc took home how mani award at the 57th grammi award', 'three'],
#  ['beyonc lost to which artist for album of the year', 'beck'],
#  ['who did beyonc perform next to dure superbowl 50', 'coldplay'],
#  ['if beyonc won three grammi in 2015 how mani was she nomin for',
#   'six award'],
#  ['on what magazin was she the cover model', 'vogu'],
#  ['who would she perform with at superbowl 50', 'coldplay'],
#  ['with what british band did beyonc perform on their album', 'coldplay'],
#  ['how mani award was beyoncé nomin for at the 57th annual grammi', 'six'],
#  ['how mani award did beyoncé win at the 57th annual grammi', 'three'],
#  ['beyoncé lost the album of the year award to which entertain', 'beck'],
#  ['which magazin did beyoncé pose for the cover make her the first black femal artist to do so',
#   'vogu'],
#  ['who did beyonc perform with at super bowl 50', 'coldplay'],
#  ['beyonc releas the song format on which onlin music servic', 'tidal'],
#  ['beyonc new singl releas befor the super bowl was call what', 'format'],
#  ['what day did beyonc releas her singl format', 'februari 6 2016'],
#  ['how was the singl releas', 'exclus'],
#  ['what was the name of the stream servic', 'tidal'],
#  ['what kind of platform was the song releas', 'music stream'],
#  ['when did beyoncé releas format', 'februari 6 2016'],
#  ['where did beyoncé exclus releas her singl format', 'tidal'],
#  ['as of april 2014 how mani album have jay z and beyonc sold togeth',
#   '300 million'],
#  ['where did beyonc becom pregnant', 'pari'],
#  ['beyonc describ what as the hardest thing she had to endur', 'miscarriag'],
#  ['who did beyonc have a relationship with', 'jay z'],
#  ['when were beyonc and jay z marri', 'april 4 2008'],
#  ['togeth how record have they sold', '300 million'],
#  ['how did beyonc deal with the miscarriag of her child', 'wrote music'],
#  ['where was beyonc when she becam pregnant', 'pari'],
#  ['in which music video did beyoncé star as jay zs girlfriend creat specul about their relationship',
#   '03 bonni clyde'],
#  ['when were beyoncé and jay z marri', 'april 4 2008'],
# ...
#  ['oxford dictionari ad which word from the 2000s dedic to beyonc',
#   'bootylici'],
#  ['what word is often use to describ beyonc', 'bootylici'],
#  ['when was the term ad to the dictionari', '2006'],
#  ['what journalist wrote that beyoncé was a sex symbol', 'touré'],
#  ['becaus of beyoncé physic shape what slang term has been use to describ her',
#   'bootylici'],
#  ['in what year was the slang term from a titl of a destini child song that is also use to describ beyoncé put in the dictionari',
#   '2006'],
#  ['how doe beyoncé say she like to dress offstag', 'sexili'],
#  ['in septemb 2010 what career area did beyonc start explor', 'model'],
#  ['beyonc first model event was at where',
#   'tom ford spring summ 2011 fashion show'],
#  ['world most beauti woman was declar to beyonc by which nation magazin',
#   'peopl'],
#  ['which month and year did gq featur beyonc on it cover', 'januari 2013'],
#  ['what tv network list beyonc as number 1 on it 100 sexiest artist list',
#   'vh1'],
#  ['who call beyonc the world most beauti woman', 'peopl'],
#  ['who call her hottest femal singer of all time', 'complex'],
#  ['when did she appear on the cover of gq', '2013'],
#  ['vh1 list her at what number on their 100 sexiest artist list', 'number 1'],
#  ['what year did beyoncé first model for tom ford', '2010'],
#  ['what magazin said beyoncé was the world most beauti woman', 'peopl'],
#  ['what titl did complex award beyoncé', 'hottest femal singer of all time'],
#  ['what museum has made sever model of beyoncé in wax',
#   'madam tussaud wax museum'],
#  ['which parent of beyonc help cowrit a book', 'her mother'],
#  ['which africanamerican woman befor beyonc had pose for si swimsuit issu',
#   'tyra bank'],
#  ['what was the titl of beyonc mother book', 'destini style'],
#  ['when was she on the sport illustr cover', '2007'],
#  ['who was she the second african american on the cover after', 'tyra bank'],
#  ['beyoncé was the second african american woman featur as a swimsuit cover on the magazin who was first',
#   'tyra bank'],
#  ['what magazin said beyoncé was the bestdress celebr', 'peopl'],
#  ['beyonc has a fan base that is refer to as what', 'the bey hive'],
#  ['befor the bey hive fan of beyonc were call what', 'the beyontourag'],
#  ['which social media compani proclaim beyonc fan are know as the bey hive',
#   'twitter'],
#  ['what is beyonc fan base call', 'bey hive'],
#  ['what did the fan use to be call', 'beyontourag'],
#  ['what is the latest term use to describ beyoncé fan', 'bey hive'],
#  ['what was the former word given to beyoncé fan', 'beyontourag'],
#  ['what word doe bey hive deriv from', 'beehiv'],
#  ['beyonc has a cloth line known as what', 'hous of deréon'],
#  ['which french magazin did beyonc show up on the cover of', 'l officiel'],
#  ['beyonc was seen wear what on the french magazin that caus controversi',
#   'blackfac and tribal makeup'],
#  ['which year did peta spark controversi with beyonc', '2006'],
#  ['what did peta critic beyonc for in 2006', 'for wear and use fur'],
#  ['what french magazin cover did the media critic', 'l officiel'],
#  ['how was she dress on the cover of lofficiel',
#   'in blackfac and tribal makeup'],
#  ['what french magazin did beyoncé appear in wear blackfac and tribal makeup',
#   'l officiel'],
#  ['what cloth line of beyoncé drew peta critic', 'hous of deréon'],
#  ['what type of magazin is lofficiel', 'french fashion magazin'],
#  ['which racial communiti gave critic to beyonc', 'african american'],
#  ['which professor from northeastern univers wrote about how race correl with these critic of beyonc',
#   'emmett price'],
#  ['which compani was accus of color beyonc hair', 'l oréal'],
#  ['what did vogu request', 'natur pictur be use'],
#  ['how did loreal respond to accus of chang pictur', 'it is categor untru'],
#  ['in addit to her light skin color what els has made part of the african american communiti critic beyoncé',
#   'costum'],
#  ['in 2007 which music professor said he believ this critic doe involv race as well',
#   'emmett price'],
#  ['who was accus of lighten beyoncé skin for an advertis', 'l oréal'],
#  ['what advertis was beyoncé skin suppos lighten in',
#   'feria hair color advertis'],
#  ['who did beyoncé tell in 2013 to onli use natur pictur of her rather than retouch imag',
#   'h m'],
#  ['artist of the decad was bestow upon beyonc from which magazin',
#   'the guardian'],
#  ['what the first year that beyonc appear on the time 100 list', '2013'],
#  ['beyonc than appear again on the time 100 list in what year', '2014'],
#  ['what did the guardian name her', 'artist of the decad'],
#  ['when did beyonc first make the time 100 list', '2013'],
#  ['when was she again on the time 100 list and on the cover', '2014'],
#  ['who said that she is the reign nation voic', 'baz luhrmann'],
#  ['who state that beyoncé is the most import musician of the 21st centuri',
#   'jodi rosen'],
#  ['which public name beyoncé the artist of the decad', 'the guardian'],
#  ['what list did beyoncé make in 2013', 'time 100 list'],
#  ['who said beyoncé is the heirappar diva of the unit state', 'baz luhrmann'],
#  ['what year was beyoncé featur both on the time 100 list as well as the cover of the issu',
#   '2014'],
#  ['which rock band cite beyonc on their third album', 'white rabbit'],
#  ['which friend learn from beyonc while prepar for the film countri strong',
#   'gwyneth paltrow'],
#  ['nicki minaj becam a spokesperson for which brand of soda after see beyonc involv with it',
#   'pepsi'],
#  ['what influenc nicki minaj to join the pepsi global campaign',
#   'beyoncé pepsi commerci'],
#  ['which band list beyonc as an inspir on their latest album', 'white rabbit'],
#  ['what about beyonc has influenc mani entertain', 'work'],
#  ['for what film was paltrow studi beyonc', 'countri strong'],
#  ['which indi band said beyoncé was an inspir for one of hteir album',
#   'white rabbit'],
#  ['what was the name of the white rabbit album', 'milk famous'],
#  ['who studi beyoncé dure live concert for research for a film music role',
#   'gwyneth paltrow'],
#  ['what was the name of the film that gwyneth paltrow star in as a musician',
#   'countri strong'],
#  ['beyoncé pepsi commerci inspir which star to join pepsi global campaign in 2012',
#   'nicki minaj'],
#  ['vh1 declar what song the greatest song of the 2000s', 'crazi in love'],
#  ['how mani grammi award did crazi in love win', 'two'],
#  ['how mani did crazi in love sell to becom one of the greatest sell singl in histori',
#   '8 million'],
#  ['what type of organ was name after beyonc in 2012', 'fli'],
#  ['a place for beyonc in the rock and roll hall of fame was award when',
#   'juli 2014'],
#  ['which of beyonc song was call greatest song of the 2000s', 'crazi in love'],
#  ['how mani grammi award did crazi in love get', 'earn two grammi award'],
#  ['how mani copi did crazi in love sell', 'around 8 million copi'],
#  ['who releas the singl girl love beyonc', 'drake'],
#  ['which public consid crazi in love to be one of the top 500 song of all time',
#   'roll stone'],
#  ['who sang girl love beyoncé in 2013', 'drake'],
#  ['what did bryan lessard name after beyoncé', 'a speci of hors fli'],
#  ['how mani copi of her album as beyonc sold in the us', '15 million'],
#  ['total worldwid how mani record as beyonc sold', '118 million'],
#  ['how mani certif was beyonc award by the riaa', '64'],
#  ['when beyonc was with destini child how mani album did she manag to sell',
#   '60 million'],
#  ['who was the first femal to achiev the intern artist award at the american music award',
#   'beyoncé'],
#  ['how mani album has beyonc as a solo artist sold in the us', '15 million'],
#  ['how mani has she sold worldwid', '118 million'],
#  ['how mani record has she sold with destini child', '60 million'],
#  ['when did she receiv the legend award', '2008 world music award'],
#  ['how mani music certif has she receiv in the 2000s', '64 certif'],
#  ['how mani record has beyoncé sold in the unit state', 'over 15 million'],
#  ['how mani record has beyoncé sold throughout the world', 'over 118 million'],
#  ['who cite beyoncé as be the top certifi artist of the 2000s',
#   'the record industri associ of america'],
#  ['how mani certif did riaa give beyoncé', '64'],
#  ['when did beyoncé receiv the legend award', 'the 2008 world music award'],
#  ['how mani grammi has beyonc won total with and without destini child', '20'],
#  ['who is the onli other woman with more grammi award than beyonc',
#   'alison krauss'],
#  ['beyonc has been award how mani grammi nomin', '52'],
#  ['beyonc hold the record for how mani win in one night by a femal', 'six'],
#  ['how mani award at the broadcast film critic associ award in 2006 did beyonc bring home',
#   'two'],
#  ['how mani grammi has beyonc won', '20 grammi award'],
#  ['how mani grammi nomin doe beyonc have', '52 nomin'],
#  ['when did she set the record for most grammi award won in one night',
#   '2010'],
#  ['who tie her record for most grammi won in one night in 2012', 'adel'],
#  ['how mani grammi has beyoncé won', '20'],
#  ['how mani grammi nomin has beyoncé had', '52'],
#  ['what beyoncé song was song of the year on 2010',
#   'singl ladi put a ring on it'],
#  ['what movi had beyoncé nomin as best actress for golden globe award',
#   'dreamgirl'],
#  ['which soda compani has beyonc partner with sinc 2002', 'pepsi'],
#  ['pepsi paid beyonc how much in 2012 for her endors', '50 million'],
#  ['which organ wrote a letter to beyonc after her pepsi endors deal',
#   'the center for scienc in the public interest cspinet'],
#  ['what percentag of peopl were posit about beyonc endors of pepsi', '70'],
#  ['when did beyonc begin do pepsi advetis', '2002'],
#  ['who was in the commerci with beyonc in 2004',
#   'britney spears pink and enriqu iglesia'],
#  ['what did she agre to do for 50 million dollar in 2012', 'endors pepsi'],
#  ['who sent her a letter ask that she reconsid the pepsi deal',
#   'center for scienc in the public interest'],
#  ['what soft drink compani has beyoncé work with sinc 2002', 'pepsi'],
#  ['how much did beyoncé get for a deal with a soft drink compani in 2012',
#   '50 million'],
#  ['who ask her to chang her mind about the soft drink deal due to the natur of the product',
#   'the center for scienc in the public interest cspinet'],
#  ['what organ discov that the advertis beyoncé did for the soft drink compani were 70 posit',
#   'netbas'],
#  ['beyonc work with who on her perfum true star and true star gold',
#   'tommi hilfig'],
#  ['the world best sell celebr perfum line belong to whom', 'beyoncé'],
#  ['beyonc first fragranc had what name', 'heat'],
#  ['the mrs carter show limit edit was releas in what year', '2013'],
#  ['how much money did the mrs carter show limit edit fragranc make',
#   '400 million'],
#  ['what was beyonc 2010 perfum call', 'heat'],
#  ['when was her second perfum heat rush releas', '2011'],
#  ['what was beyonc third perfum name', 'puls'],
#  ['how mani edit of heat have been launch', 'six edit'],
#  ['which emporio armani fragranc did beyoncé promot in 2007', 'diamond'],
#  ['what year did beyoncé introduc her first fragranc', '2010'],
#  ['what was beyoncé first fragranc call', 'heat'],
#  ['how mani edit of heat exist', 'six'],
#  ['how young was beyonc when she acquir deal from american express and loreal',
#   '18'],
#  ['what was the name of the video game that was cancel for beyonc',
#   'starpower beyoncé'],
#  ['when did beyonc begin her deal with name brand', 'sinc the age of 18'],
#  ['how mani peopl lost job when beyonc left the video game deal', '70 staff'],
#  ['how was the suit settl', 'out of court'],
#  ['what was the name of the video game', 'starpower beyoncé'],
#  ['what video game did beyoncé back out of', 'starpower beyoncé'],
#  ['what compani was produc the video game', 'gatef'],
#  ['how mani peopl lost their job over beyoncé back out of the deal', '70'],
#  ['when was the disagr settl out of court', 'june 2013'],
#  ['who did bayonc manag go into busi with in 2014', 'fashion retail topshop'],
#  ['after their agreement togeth beyonc and topshop new busi was call what',
#   'parkwood topshop athlet ltd'],
#  ['what type of cloth doe parkwood topshop athlet ltd produc', 'activewear'],
#  ['the compani and product were set to be in store when', 'fall of 2015'],
#  ['who did beyonc partner with in london', 'topshop'],
#  ['when will the new line launch', '2015'],
#  ['what is the name of beyoncé manag compani', 'parkwood entertain'],
#  ['who did beyoncé and parkwood entertain partner with in octob 2014',
#   'topshop'],
#  ['where is topshop locat', 'london'],
#  ['what was the new divis of topshop becaus of the partnership', 'activewear'],
#  ['when was it discov beyonc was a coowner of the music servic tidal',
#   'march 30 2015'],
#  ['the parent compani of tidal becam under the ownership of whom in 2015',
#   'jay z'],
#  ['when was it announc that beyonc was a coowner in tidal', 'march 30 2015'],
#  ['what kind of servic is tidal', 'music stream servic'],
#  ['what is a critic of other stream servic', 'low payout of royalti'],
#  ['what music stream system is beyoncé part owner of', 'tidal'],
#  ['what is the parent compani of the music servic beyoncé own part of',
#   'aspiro'],
#  ['who acquir the parent compani of the music servic beyoncé own part of',
#   'jay z'],
#  ['what music servic is accus of provid low royalti amount', 'spotifi'],
#  ['hous of dereon becam known through beyonc and which of beyonc relat',
#   'her mother'],
#  ['beyonc grandma name was', 'agnèz deréon'],
#  ['beyonc famili compani name is what', 'beyond product'],
#  ['what type of garment are sold by beyonc cloth line',
#   'sportswear denim offer with fur outerwear and accessori that includ handbag and footwear'],
#  ['which two countri can you purchas beyonc cloth line', 'us and canada'],
#  ['who partner with beyonc to start the cloth line dereon', 'her mother'],
#  ['when did beyonc and her mother start dereon', '2005'],
#  ['who was the busi name for in beyonc famili', 'grandmother agnèz deréon'],
#  ['where were item from the cloth line display',
#   'in destini child show and tour'],
#  ['who share in the hous of deréon fashion line introduct with beyoncé',
#   'her mother'],
#  ['what is the name of the hous of deréon junior collect', 'deréon'],
#  ['what type of accessori compani did beyonc partner with in 2005', 'shoe'],
#  ['in 2010 beyonc releas dereon to what countri', 'brazil'],
#  ['backtoschool shop was introduc in what year of beyonc cloth line', '2009'],
#  ['what did beyonc fashion diva featur', 'hous of deréon collect'],
#  ['what new idea did beyonc and her mother launch in 2009',
#   'sasha fierc for deréon'],
#  ['when did beyonc partner with ca to sell fashion in brazil', 'may 27 2010'],
#  ['what compani did beyoncé get togeth with in 2005 to add shoe to her fashion',
#   'hous of brand'],
#  ['what was the name of the game put out by starwav mobil in 2008 that featur beyoncé fashion',
#   'beyoncé fashion diva'],
#  ['what was the name of the junior fashion launch in 2009 by beyoncé and her mother',
#   'sasha fierc for deréon'],
#  ['who did beyoncé team up with in 2010 to get her fashion into brazil',
#   'c a'],
#  ['sasha fierc for deréon fashion were sold at store that includ maci and what other store',
#   'dillard'],
#  ['beyonc dure octob 2014 partner with whom to produc an outdoor line of cloth',
#   'topshop'],
#  ['beyonc and topshop first product were to be sold in store when',
#   'autumn 2015'],
#  ['what is the new busi call', 'parkwood topshop athlet ltd'],
#  ['what is beyonc percentag of ownership in the new ventur', '50'],
#  ['when will the full line appear', 'april 2016'],
#  ['what compani did beyoncé contract with to sell cloth in england',
#   'topshop'],
#  ['what is the name of the equal partnership fashion line between beyoncé and the british compani to come out in 2016',
#   'parkwood topshop athlet ltd'],
#  ['what type of cloth doe the british partnership with beyoncé sell',
#   'activewear'],
#  ['what nation disast caus beyonc to creat the survivor foundat',
#   'hurrican katrina'],
#  ['how much cash did beyonc put into the ventur the survivor foundat at startup',
#   '250 000'],
#  ['what hurrican year later after katrina did the organ provid support for',
#   'ike'],
#  ['what did beyonc and rowland found in 2005', 'the survivor foundat'],
#  ...]
